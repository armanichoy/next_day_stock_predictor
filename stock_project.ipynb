# %%
import yfinance as yf
import pandas as pd

from src import functions as f

# %load_ext autoreload
# %autoreload 2

# %%
f.load_tables('tsm')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1997-10-09 00:00:00-04:00    5.646040    6.562691    5.646040    6.323565
# 1997-10-10 00:00:00-04:00    7.014374    7.040944    6.363419    6.615830
# 1997-10-13 00:00:00-04:00    6.629115    6.629115    6.443128    6.469698
# 1997-10-14 00:00:00-04:00    6.416558    6.429843    6.031299    6.204002
# 1997-10-15 00:00:00-04:00    5.818742    6.044584    5.805458    6.031299
# ...                               ...         ...         ...         ...
# 2025-01-14 00:00:00-05:00  205.190002  206.259995  198.500000  201.449997
# 2025-01-15 00:00:00-05:00  202.490005  209.039993  199.350006  206.800003
# 2025-01-16 00:00:00-05:00  218.889999  221.949997  213.169998  214.789993
# 2025-01-17 00:00:00-05:00  215.169998  215.679993  211.059998  211.500000
# 2025-01-21 00:00:00-05:00  214.460007  220.149994  212.050003  218.699997
#
#                             Adj Close    Volume  Dividends  Stock Splits
# ...

# %%
nvda_raw, last_day, nvda_df=f.transform_table(f.load_tables('tsm'))
nvda_df
# Out:
#                                 Close  std_23days  z_23days  target  \
# Date
# 1997-11-20 00:00:00-05:00    4.437123    0.434144 -0.478958       2
# 1997-11-21 00:00:00-05:00    4.662965    0.406946  0.116387       1
# 1997-11-24 00:00:00-05:00    4.556686    0.406514 -0.127879       2
# 1997-11-25 00:00:00-05:00    4.676250    0.404982  0.141198       1
# 1997-11-26 00:00:00-05:00    4.596541    0.394538 -0.101015       2
# ...                               ...         ...       ...     ...
# 2025-01-14 00:00:00-05:00  201.449997    6.689995 -0.078703       2
# 2025-01-15 00:00:00-05:00  206.800003    6.387368  0.654009       2
# 2025-01-16 00:00:00-05:00  214.789993    6.617903  1.705912       1
# 2025-01-17 00:00:00-05:00  211.500000    6.270733  1.136751       2
# 2025-01-21 00:00:00-05:00  218.699997    6.893054  1.966945       2
#
#                             mu_23days  month  dow  pct_top_wick  pct_body  \
# Date
# ...

# %%
last_day
# Out:
# Close              218.699997
# std_23days           6.893054
# z_23days             1.966945
# target               2.000000
# mu_23days          205.141739
# month                1.000000
# dow                  1.000000
# pct_top_wick         0.179012
# pct_body             0.523456
# pct_bottom_wick      0.297532
# pct_gap_up_down      0.640695
# z_top_30days        -0.380924
# z_body_30days        0.058479
# z_bottom_30days      0.241430
# z_gap_30days         0.669538
# Name: 2025-01-21 00:00:00-05:00, dtype: float64

# %%
report, model, importances = f.train_test_model(nvda_df)
report
# Out:
# /Users/armanichoy/Documents/stock_project/myenv/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [14:50:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Accuracy: 0.38
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.38      0.36      0.37       584
#            1       0.37      0.39      0.38       712
#            2       0.38      0.38      0.38       754
#
#     accuracy                           0.38      2050
#    macro avg       0.38      0.37      0.37      2050
# weighted avg       0.38      0.38      0.38      2050

# %%
importances
# Out:
# array([0.07509989, 0.07330181, 0.07201274, 0.08438728, 0.06626642,
#        0.06433403, 0.06739803, 0.07166193, 0.07037644, 0.06485055,
#        0.07279305, 0.07691936, 0.07047725, 0.07012116], dtype=float32)

# %%
nvda_df['target'].value_counts()
# Out:
# target
# 2    2454
# 1    2391
# 0    1988
# Name: count, dtype: int64

# %%
last_day_ = last_day.drop(['target'])
last_day_
# Out:
# Close              218.699997
# std_23days           6.893054
# z_23days             1.966945
# mu_23days          205.141739
# month                1.000000
# dow                  1.000000
# pct_top_wick         0.179012
# pct_body             0.523456
# pct_bottom_wick      0.297532
# pct_gap_up_down      0.640695
# z_top_30days        -0.380924
# z_body_30days        0.058479
# z_bottom_30days      0.241430
# z_gap_30days         0.669538
# Name: 2025-01-21 00:00:00-05:00, dtype: float64

# %%
last_day_df = last_day_.to_frame().T
model.predict(last_day_df)[0]
# Out:
# 2

# %%
model.predict_proba(last_day_df)[0][2]
# Out:
# 0.8003921

# %%
nvda_df
# Out:
#                                 Close  std_23days  z_23days  target  \
# Date
# 1997-11-20 00:00:00-05:00    4.437123    0.434144 -0.478958       2
# 1997-11-21 00:00:00-05:00    4.662965    0.406946  0.116387       1
# 1997-11-24 00:00:00-05:00    4.556686    0.406514 -0.127879       2
# 1997-11-25 00:00:00-05:00    4.676250    0.404982  0.141198       1
# 1997-11-26 00:00:00-05:00    4.596541    0.394538 -0.101015       2
# ...                               ...         ...       ...     ...
# 2025-01-14 00:00:00-05:00  201.449997    6.689995 -0.078703       2
# 2025-01-15 00:00:00-05:00  206.800003    6.387368  0.654009       2
# 2025-01-16 00:00:00-05:00  214.789993    6.617903  1.705912       1
# 2025-01-17 00:00:00-05:00  211.500000    6.270733  1.136751       2
# 2025-01-21 00:00:00-05:00  218.699997    6.893054  1.966945       2
#
#                             mu_23days  month  dow  pct_top_wick  pct_body  \
# Date
# ...

# %%
nvda_raw
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1997-10-09 00:00:00-04:00    5.646040    6.562691    5.646040    6.323565
# 1997-10-10 00:00:00-04:00    7.014374    7.040944    6.363419    6.615830
# 1997-10-13 00:00:00-04:00    6.629115    6.629115    6.443128    6.469698
# 1997-10-14 00:00:00-04:00    6.416558    6.429843    6.031299    6.204002
# 1997-10-15 00:00:00-04:00    5.818742    6.044584    5.805458    6.031299
# ...                               ...         ...         ...         ...
# 2025-01-14 00:00:00-05:00  205.190002  206.259995  198.500000  201.449997
# 2025-01-15 00:00:00-05:00  202.490005  209.039993  199.350006  206.800003
# 2025-01-16 00:00:00-05:00  218.889999  221.949997  213.169998  214.789993
# 2025-01-17 00:00:00-05:00  215.169998  215.679993  211.059998  211.500000
# 2025-01-21 00:00:00-05:00  214.460007  220.149994  212.050003  218.699997
#
#                             Adj Close    Volume  Dividends  Stock Splits
# ...
